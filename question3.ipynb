# %%
import pandas as pd
from utils import DATASETS

from car import XMETRICS, YMETRICS, get_description, metrics

table = {datasetKey: metrics(datasetKey) for datasetKey in DATASETS}
# Out:
# genbase:train - exists, not redownloading
# rcv1subset4:train - exists, not redownloading
# yeast:train - exists, not redownloading
# tmc2007_500:train - exists, not redownloading
# enron:train - exists, not redownloading
# delicious:train - exists, not redownloading
# mediamill:train - exists, not redownloading
# scene:train - exists, not redownloading
# birds:train - exists, not redownloading
# rcv1subset5:train - exists, not redownloading
# rcv1subset2:train - exists, not redownloading
# rcv1subset3:train - exists, not redownloading
# Corel5k:train - exists, not redownloading
# emotions:train - exists, not redownloading
# rcv1subset1:train - exists, not redownloading
# medical:train - exists, not redownloading
# bibtex:train - exists, not redownloading

# %%
dataframe = pd.DataFrame(table)
dataframe.transpose()
dataframe.style.format('{:,}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_fbc44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbc44_level0_col0" class="col_heading level0 col0" >genbase</th>
#       <th id="T_fbc44_level0_col1" class="col_heading level0 col1" >rcv1subset4</th>
#       <th id="T_fbc44_level0_col2" class="col_heading level0 col2" >yeast</th>
#       <th id="T_fbc44_level0_col3" class="col_heading level0 col3" >tmc2007_500</th>
#       <th id="T_fbc44_level0_col4" class="col_heading level0 col4" >enron</th>
#       <th id="T_fbc44_level0_col5" class="col_heading level0 col5" >delicious</th>
#       <th id="T_fbc44_level0_col6" class="col_heading level0 col6" >mediamill</th>
#       <th id="T_fbc44_level0_col7" class="col_heading level0 col7" >scene</th>
#       <th id="T_fbc44_level0_col8" class="col_heading level0 col8" >birds</th>
#       <th id="T_fbc44_level0_col9" class="col_heading level0 col9" >rcv1subset5</th>
# ...
